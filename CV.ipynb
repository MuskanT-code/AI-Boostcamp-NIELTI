# %% [markdown]
# <a href="https://colab.research.google.com/github/MuskanT-code/AI-Boostcamp-NIELTI/blob/main/CV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
image_path = '/content/Apple.jpg'
#Read the image using cv2.imread()
img = cv2.imread(image_path)

#check if the image was loaded successfully
if img is None:
  print(f"Error: Image not fount at {image_path} or unable to load.")
else:
  #Display the image using cv2_imshow
  cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x225>
